# %% [markdown]
# Before running any files, do the following:
#
# 1. install spaCy: https://spacy.io/usage
# 2. clone TAACO repo in same parent: https://github.com/LCR-ADS-Lab/TAACO
#     - E.g., **GitHub**/COAS-GenAI-feedback and **GitHub**/TAACO share the same parent folder **GitHub**

# %%
import os
from pathlib import Path

initial_path = os.getcwd()
path_to_TAACO = Path(initial_path).parent.joinpath('TAACO')
os.chdir(path_to_TAACO)

from TAACOnoGUI import runTAACO

os.chdir(initial_path)

# %%
def taaco_on_folder_of_files(folder_name, output_csv_name, sampleVars = {"sourceKeyOverlap" : False, "sourceLSA" : False, "sourceLDA" : False, "sourceWord2vec" : False, "wordsAll" : True, "wordsContent" : True, "wordsFunction" : True, "wordsNoun" : True, "wordsPronoun" : True, "wordsArgument" : True, "wordsVerb" : True, "wordsAdjective" : True, "wordsAdverb" : True, "overlapSentence" : False, "overlapParagraph" : False, "overlapAdjacent" : False, "overlapAdjacent2" : False, "otherTTR" : True, "otherConnectives" : True, "otherGivenness" : True, "overlapLSA" : False, "overlapLDA" : False, "overlapWord2vec" : False, "overlapSynonym" : False, "overlapNgrams" : False, "outputTagged" : False, "outputDiagnostic" : False}):
    # import folder to TAACO folder for processing
    if not os.path.exists(Path(path_to_TAACO).joinpath(folder_name)):
        os.mkdir(Path(path_to_TAACO).joinpath(folder_name))
    for file in os.listdir(Path(initial_path).joinpath(folder_name)):
        os.replace(Path(initial_path).joinpath(folder_name).joinpath(file), Path(path_to_TAACO).joinpath(folder_name).joinpath(file))
    
    # change working directory and run TAACO
    os.chdir(path_to_TAACO)
    csv_file_name = f'{output_csv_name}.csv'
    runTAACO(f'{folder_name}/', csv_file_name, sampleVars)

    # move folder and output back to main repo
    for file in os.listdir(Path(path_to_TAACO).joinpath(folder_name)):
        os.replace(Path(path_to_TAACO).joinpath(folder_name).joinpath(file), Path(initial_path).joinpath(folder_name).joinpath(file))
    Path(path_to_TAACO).joinpath(folder_name).rmdir()
    os.replace(Path(path_to_TAACO).joinpath(csv_file_name), Path(initial_path).joinpath(csv_file_name))
    
    # return to original cwd
    os.chdir(initial_path)

# %%
# Test TAACO install

taaco_on_folder_of_files('test_TAACO_install_file', 'test_output')
# Out:
# Loading Spacy
# Loading Spacy Model
# Starting TAACO...
# outdir: test_output.csv
# key_out_dir:
# TAACO is processing 1 of 2 files
# TAACO is processing 2 of 2 files
# Processed 2 Files

# %%
# Run TAACO with real data
taaco_on_folder_of_files('student_response_txt_files', 'taaco_results')
# Out:
# Loading Spacy
# Loading Spacy Model
# Starting TAACO...
# outdir: taaco_results.csv
# key_out_dir:
# TAACO is processing 1 of 171 files
# TAACO is processing 2 of 171 files
# TAACO is processing 3 of 171 files
# TAACO is processing 4 of 171 files
# TAACO is processing 5 of 171 files
# TAACO is processing 6 of 171 files
# TAACO is processing 7 of 171 files
# TAACO is processing 8 of 171 files
# TAACO is processing 9 of 171 files
# TAACO is processing 10 of 171 files
# TAACO is processing 11 of 171 files
# TAACO is processing 12 of 171 files
# TAACO is processing 13 of 171 files
# TAACO is processing 14 of 171 files
# TAACO is processing 15 of 171 files
# TAACO is processing 16 of 171 files
# TAACO is processing 17 of 171 files
# TAACO is processing 18 of 171 files
# TAACO is processing 19 of 171 files
# TAACO is processing 20 of 171 files
# TAACO is processing 21 of 171 files
# TAACO is processing 22 of 171 files
# TAACO is processing 23 of 171 files
# TAACO is processing 24 of 171 files
# TAACO is processing 25 of 171 files
# TAACO is processing 26 of 171 files
# TAACO is processing 27 of 171 files
# TAACO is processing 28 of 171 files
# TAACO is processing 29 of 171 files
# TAACO is processing 30 of 171 files
# TAACO is processing 31 of 171 files
# TAACO is processing 32 of 171 files
# TAACO is processing 33 of 171 files
# TAACO is processing 34 of 171 files
# TAACO is processing 35 of 171 files
# TAACO is processing 36 of 171 files
# TAACO is processing 37 of 171 files
# TAACO is processing 38 of 171 files
# TAACO is processing 39 of 171 files
# TAACO is processing 40 of 171 files
# TAACO is processing 41 of 171 files
# TAACO is processing 42 of 171 files
# TAACO is processing 43 of 171 files
# TAACO is processing 44 of 171 files
# TAACO is processing 45 of 171 files
# TAACO is processing 46 of 171 files
# TAACO is processing 47 of 171 files
# TAACO is processing 48 of 171 files
# TAACO is processing 49 of 171 files
# TAACO is processing 50 of 171 files
# TAACO is processing 51 of 171 files
# TAACO is processing 52 of 171 files
# TAACO is processing 53 of 171 files
# TAACO is processing 54 of 171 files
# TAACO is processing 55 of 171 files
# TAACO is processing 56 of 171 files
# TAACO is processing 57 of 171 files
# TAACO is processing 58 of 171 files
# TAACO is processing 59 of 171 files
# TAACO is processing 60 of 171 files
# TAACO is processing 61 of 171 files
# TAACO is processing 62 of 171 files
# TAACO is processing 63 of 171 files
# TAACO is processing 64 of 171 files
# TAACO is processing 65 of 171 files
# TAACO is processing 66 of 171 files
# TAACO is processing 67 of 171 files
# TAACO is processing 68 of 171 files
# TAACO is processing 69 of 171 files
# TAACO is processing 70 of 171 files
# TAACO is processing 71 of 171 files
# TAACO is processing 72 of 171 files
# TAACO is processing 73 of 171 files
# TAACO is processing 74 of 171 files
# TAACO is processing 75 of 171 files
# TAACO is processing 76 of 171 files
# TAACO is processing 77 of 171 files
# TAACO is processing 78 of 171 files
# TAACO is processing 79 of 171 files
# TAACO is processing 80 of 171 files
# TAACO is processing 81 of 171 files
# TAACO is processing 82 of 171 files
# TAACO is processing 83 of 171 files
# TAACO is processing 84 of 171 files
# TAACO is processing 85 of 171 files
# TAACO is processing 86 of 171 files
# TAACO is processing 87 of 171 files
# TAACO is processing 88 of 171 files
# TAACO is processing 89 of 171 files
# TAACO is processing 90 of 171 files
# TAACO is processing 91 of 171 files
# TAACO is processing 92 of 171 files
# TAACO is processing 93 of 171 files
# TAACO is processing 94 of 171 files
# TAACO is processing 95 of 171 files
# TAACO is processing 96 of 171 files
# TAACO is processing 97 of 171 files
# TAACO is processing 98 of 171 files
# TAACO is processing 99 of 171 files
# TAACO is processing 100 of 171 files
# TAACO is processing 101 of 171 files
# TAACO is processing 102 of 171 files
# TAACO is processing 103 of 171 files
# TAACO is processing 104 of 171 files
# TAACO is processing 105 of 171 files
# TAACO is processing 106 of 171 files
# TAACO is processing 107 of 171 files
# TAACO is processing 108 of 171 files
# TAACO is processing 109 of 171 files
# TAACO is processing 110 of 171 files
# TAACO is processing 111 of 171 files
# TAACO is processing 112 of 171 files
# TAACO is processing 113 of 171 files
# TAACO is processing 114 of 171 files
# TAACO is processing 115 of 171 files
# TAACO is processing 116 of 171 files
# TAACO is processing 117 of 171 files
# TAACO is processing 118 of 171 files
# TAACO is processing 119 of 171 files
# TAACO is processing 120 of 171 files
# TAACO is processing 121 of 171 files
# TAACO is processing 122 of 171 files
# TAACO is processing 123 of 171 files
# TAACO is processing 124 of 171 files
# TAACO is processing 125 of 171 files
# TAACO is processing 126 of 171 files
# TAACO is processing 127 of 171 files
# TAACO is processing 128 of 171 files
# TAACO is processing 129 of 171 files
# TAACO is processing 130 of 171 files
# TAACO is processing 131 of 171 files
# TAACO is processing 132 of 171 files
# TAACO is processing 133 of 171 files
# TAACO is processing 134 of 171 files
# TAACO is processing 135 of 171 files
# TAACO is processing 136 of 171 files
# TAACO is processing 137 of 171 files
# TAACO is processing 138 of 171 files
# TAACO is processing 139 of 171 files
# TAACO is processing 140 of 171 files
# TAACO is processing 141 of 171 files
# TAACO is processing 142 of 171 files
# TAACO is processing 143 of 171 files
# TAACO is processing 144 of 171 files
# TAACO is processing 145 of 171 files
# TAACO is processing 146 of 171 files
# TAACO is processing 147 of 171 files
# TAACO is processing 148 of 171 files
# TAACO is processing 149 of 171 files
# TAACO is processing 150 of 171 files
# TAACO is processing 151 of 171 files
# TAACO is processing 152 of 171 files
# TAACO is processing 153 of 171 files
# TAACO is processing 154 of 171 files
# TAACO is processing 155 of 171 files
# TAACO is processing 156 of 171 files
# TAACO is processing 157 of 171 files
# TAACO is processing 158 of 171 files
# TAACO is processing 159 of 171 files
# TAACO is processing 160 of 171 files
# TAACO is processing 161 of 171 files
# TAACO is processing 162 of 171 files
# TAACO is processing 163 of 171 files
# TAACO is processing 164 of 171 files
# TAACO is processing 165 of 171 files
# TAACO is processing 166 of 171 files
# TAACO is processing 167 of 171 files
# TAACO is processing 168 of 171 files
# TAACO is processing 169 of 171 files
# TAACO is processing 170 of 171 files
# TAACO is processing 171 of 171 files
# Processed 171 Files
